# %% [markdown]
# # 001 Staging

# %% [markdown]
# DB Connection

# %%
import yaml
import psycopg2
from psycopg2 import sql
from sqlalchemy import create_engine, text
import pandas as pd

# %%
def load_config(file_path="config.yaml"):
    with open(file_path, "r") as file:
        return yaml.safe_load(file)

# %%
config = load_config()
db_config = config["database"]

# Load credentials
db_user = db_config["user"]
db_password = db_config["password"]
db_host = db_config["host"]
db_port = db_config["port"]
db_name = db_config["name"]

# DB connection
conn = psycopg2.connect(
    dbname="postgres",
    user=db_user,
    password=db_password,
    host=db_host,
    port=db_port
)
conn.autocommit = True

# %% [markdown]
# Check if DB Exists

# %%
db_name = "etl_db_final_workshop"
try:
    with conn.cursor() as cur:
        cur.execute(sql.SQL("CREATE DATABASE {}").format(sql.Identifier(db_name)))
        print(f"Base de datos '{db_name}' creada exitosamente.")
except psycopg2.errors.DuplicateDatabase:
    print(f"La base de datos '{db_name}' ya existe.")
finally:
    conn.close()
# Out:
# La base de datos 'etl_db_final_workshop' ya existe.

# %% [markdown]
# Casting datatypes

# %%
import pandas as pd
import numpy as np

# Definir tipos de datos optimizados
dtypes = {
    "summary_code": np.uint16,
    "http_code": np.uint16,
    "total_time_ms": np.uint16,
    
    **{col: np.float32 for col in [
        "time_ms_accessory_detector_near_img", "time_ms_accessory_detector_far_img",
        "queue_time_ms_accessory_detector_near_img", "queue_time_ms_accessory_detector_far_img",
        "time_ms_face_detector_near_img", "time_ms_face_detector_far_img",
        "queue_time_ms_face_detector_near_img", "queue_time_ms_face_detector_far_img",
        "time_ms_liqe_near_img", "time_ms_liqe_far_img",
        "queue_time_ms_liqe_near_img", "queue_time_ms_liqe_far_img",
        "time_ms_topiq_near_img", "time_ms_topiq_far_img",
        "queue_time_ms_topiq_near_img", "queue_time_ms_topiq_far_img",
        "time_ms_classic_metrics_near_img", "time_ms_classic_metrics_far_img",
        "time_ms_as_35_selfies_near_img", "time_ms_as_35_selfies_far_img",
        "queue_time_ms_as_35_selfies_near_img", "queue_time_ms_as_35_selfies_far_img",
        "time_ms_ibeta2_crops_near_img", "time_ms_ibeta2_crops_far_img",
        "queue_time_ms_ibeta2_crops_near_img", "queue_time_ms_ibeta2_crops_far_img",
        "time_ms_ibeta2_full_near_img", "time_ms_ibeta2_full_far_img",
        "queue_time_ms_ibeta2_full_near_img", "queue_time_ms_ibeta2_full_far_img",
        "time_ms_ibeta2_clip_near_img", "time_ms_ibeta2_clip_far_img",
        "queue_time_ms_ibeta2_clip_near_img", "queue_time_ms_ibeta2_clip_far_img",
        "time_ms_geometry_check", "queue_time_ms_geometry_check"
    ]},

    **{col: np.float32 for col in [
        "score_liqe_near_img", "score_liqe_far_img",
        "score_topiq_near_img", "score_topiq_far_img",
        "score_sharpness_classic_metrics_near_img", "score_sharpness_classic_metrics_far_img",
        "score_colorfulness_classic_metrics_near_img", "score_colorfulness_classic_metrics_far_img",
        "score_contrast_classic_metrics_near_img", "score_contrast_classic_metrics_far_img",
        "score_brightness_classic_metrics_near_img", "score_brightness_classic_metrics_far_img",
        "score_blur_score_classic_metrics_near_img", "score_blur_score_classic_metrics_far_img",
        "score_svd_score_classic_metrics_near_img", "score_svd_score_classic_metrics_far_img",
        "prob_as_35_selfies_near_img", "prob_as_35_selfies_far_img",
        "prob_ibeta2_crops_near_img", "prob_ibeta2_crops_far_img",
        "prob_ibeta2_full_near_img", "prob_ibeta2_full_far_img",
        "prob_ibeta2_clip_near_img", "prob_ibeta2_clip_far_img",
        "prob_as_heuristics_near_img", "prob_as_heuristics_far_img"
    ]},

    "summary_status": "category",
    "summary_desc": "category",
    "service": "category",
    "convenio": "category",

    "api_hash": str,
    "user_name": str,
    "file_token": str,
    "procesoConvenioGuid": str,
    "documento": str,
    "date": str,
}

# %% [markdown]
# Load Data

# %%
df = pd.read_csv("../data/processed/anonymized_data.csv", dtype=dtypes)
print(df.columns)
print(df.info())
df.head()
# Out:
# Index(['api_hash', 'user_name', 'file_token', 'service', 'summary_code',
#        'summary_status', 'summary_desc', 'http_code', 'total_time_ms', 'date',
#        'procesoConvenioGuid', 'convenio', 'documento',
#        'img_size_near_img_width', 'img_size_near_img_height',
#        'img_size_far_img_width', 'img_size_far_img_height',
#        'score_liqe_near_img', 'score_liqe_far_img', 'score_topiq_near_img',
#        'score_topiq_far_img', 'score_sharpness_classic_metrics_near_img',
#        'score_sharpness_classic_metrics_far_img',
#        'score_colorfulness_classic_metrics_near_img',
#        'score_colorfulness_classic_metrics_far_img',
#        'score_contrast_classic_metrics_near_img',
#        'score_contrast_classic_metrics_far_img',
#        'score_brightness_classic_metrics_near_img',
#        'score_brightness_classic_metrics_far_img',
#        'score_blur_score_classic_metrics_near_img',
#        'score_blur_score_classic_metrics_far_img',
#        'score_svd_score_classic_metrics_near_img',
#        'score_svd_score_classic_metrics_far_img',
#        'prob_as_35_selfies_near_img', 'prob_as_35_selfies_far_img',
#        'prob_ibeta2_crops_near_img', 'prob_ibeta2_crops_far_img',
#        'prob_ibeta2_full_near_img', 'prob_ibeta2_full_far_img',
#        'prob_ibeta2_clip_near_img', 'prob_ibeta2_clip_far_img',
#        'prob_as_heuristics_near_img', 'prob_as_heuristics_far_img',
#        'time_ms_accessory_detector_near_img',
#        'time_ms_accessory_detector_far_img',
#        'queue_time_ms_accessory_detector_near_img',
#        'queue_time_ms_accessory_detector_far_img',
#        'time_ms_face_detector_near_img', 'time_ms_face_detector_far_img',
#        'queue_time_ms_face_detector_near_img',
#        'queue_time_ms_face_detector_far_img', 'time_ms_liqe_near_img',
#        'time_ms_liqe_far_img', 'queue_time_ms_liqe_near_img',
#        'queue_time_ms_liqe_far_img', 'time_ms_topiq_near_img',
#        'time_ms_topiq_far_img', 'queue_time_ms_topiq_near_img',
#        'queue_time_ms_topiq_far_img', 'time_ms_classic_metrics_near_img',
#        'time_ms_classic_metrics_far_img', 'time_ms_as_35_selfies_near_img',
#        'time_ms_as_35_selfies_far_img', 'queue_time_ms_as_35_selfies_near_img',
#        'queue_time_ms_as_35_selfies_far_img', 'time_ms_ibeta2_crops_near_img',
#        'time_ms_ibeta2_crops_far_img', 'queue_time_ms_ibeta2_crops_near_img',
#        'queue_time_ms_ibeta2_crops_far_img', 'time_ms_ibeta2_full_near_img',
#        'time_ms_ibeta2_full_far_img', 'queue_time_ms_ibeta2_full_near_img',
#        'queue_time_ms_ibeta2_full_far_img', 'time_ms_ibeta2_clip_near_img',
#        'time_ms_ibeta2_clip_far_img', 'queue_time_ms_ibeta2_clip_near_img',
#        'queue_time_ms_ibeta2_clip_far_img', 'time_ms_geometry_check',
#        'queue_time_ms_geometry_check'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14654 entries, 0 to 14653
# Data columns (total 79 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   api_hash                                     14654 non-null  object
#  1   user_name                                    14654 non-null  object
#  2   file_token                                   14654 non-null  object
#  3   service                                      14654 non-null  category
#  4   summary_code                                 14654 non-null  uint16
#  5   summary_status                               14654 non-null  category
#  6   summary_desc                                 14654 non-null  category
#  7   http_code                                    14654 non-null  uint16
#  8   total_time_ms                                14654 non-null  uint16
#  9   date                                         14654 non-null  object
#  10  procesoConvenioGuid                          14654 non-null  object
#  11  convenio                                     14654 non-null  category
#  12  documento                                    14654 non-null  object
#  13  img_size_near_img_width                      14654 non-null  int64
#  14  img_size_near_img_height                     14654 non-null  int64
#  15  img_size_far_img_width                       14654 non-null  int64
#  16  img_size_far_img_height                      14654 non-null  int64
#  17  score_liqe_near_img                          13593 non-null  float32
#  18  score_liqe_far_img                           11915 non-null  float32
#  19  score_topiq_near_img                         13593 non-null  float32
#  20  score_topiq_far_img                          11915 non-null  float32
#  21  score_sharpness_classic_metrics_near_img     13593 non-null  float32
#  22  score_sharpness_classic_metrics_far_img      11915 non-null  float32
#  23  score_colorfulness_classic_metrics_near_img  13593 non-null  float32
#  24  score_colorfulness_classic_metrics_far_img   11915 non-null  float32
#  25  score_contrast_classic_metrics_near_img      13593 non-null  float32
#  26  score_contrast_classic_metrics_far_img       11915 non-null  float32
#  27  score_brightness_classic_metrics_near_img    13593 non-null  float32
#  28  score_brightness_classic_metrics_far_img     11915 non-null  float32
#  29  score_blur_score_classic_metrics_near_img    13593 non-null  float32
#  30  score_blur_score_classic_metrics_far_img     11915 non-null  float32
#  31  score_svd_score_classic_metrics_near_img     13593 non-null  float32
#  32  score_svd_score_classic_metrics_far_img      11915 non-null  float32
#  33  prob_as_35_selfies_near_img                  10586 non-null  float32
#  34  prob_as_35_selfies_far_img                   9794 non-null   float32
#  35  prob_ibeta2_crops_near_img                   10586 non-null  float32
#  36  prob_ibeta2_crops_far_img                    9794 non-null   float32
#  37  prob_ibeta2_full_near_img                    10586 non-null  float32
#  38  prob_ibeta2_full_far_img                     9794 non-null   float32
#  39  prob_ibeta2_clip_near_img                    10586 non-null  float32
#  40  prob_ibeta2_clip_far_img                     9794 non-null   float32
#  41  prob_as_heuristics_near_img                  10586 non-null  float32
#  42  prob_as_heuristics_far_img                   9794 non-null   float32
#  43  time_ms_accessory_detector_near_img          14654 non-null  float32
#  44  time_ms_accessory_detector_far_img           14513 non-null  float32
#  45  queue_time_ms_accessory_detector_near_img    14654 non-null  float32
#  46  queue_time_ms_accessory_detector_far_img     14513 non-null  float32
#  47  time_ms_face_detector_near_img               14457 non-null  float32
#  48  time_ms_face_detector_far_img                14075 non-null  float32
#  49  queue_time_ms_face_detector_near_img         14457 non-null  float32
#  50  queue_time_ms_face_detector_far_img          14075 non-null  float32
#  51  time_ms_liqe_near_img                        13593 non-null  float32
#  52  time_ms_liqe_far_img                         11915 non-null  float32
#  53  queue_time_ms_liqe_near_img                  13593 non-null  float32
#  54  queue_time_ms_liqe_far_img                   11915 non-null  float32
#  55  time_ms_topiq_near_img                       13593 non-null  float32
#  56  time_ms_topiq_far_img                        11915 non-null  float32
#  57  queue_time_ms_topiq_near_img                 13593 non-null  float32
#  58  queue_time_ms_topiq_far_img                  11915 non-null  float32
#  59  time_ms_classic_metrics_near_img             13593 non-null  float32
#  60  time_ms_classic_metrics_far_img              11915 non-null  float32
#  61  time_ms_as_35_selfies_near_img               10586 non-null  float32
#  62  time_ms_as_35_selfies_far_img                9794 non-null   float32
#  63  queue_time_ms_as_35_selfies_near_img         10586 non-null  float32
#  64  queue_time_ms_as_35_selfies_far_img          9794 non-null   float32
#  65  time_ms_ibeta2_crops_near_img                10586 non-null  float32
#  66  time_ms_ibeta2_crops_far_img                 9794 non-null   float32
#  67  queue_time_ms_ibeta2_crops_near_img          10586 non-null  float32
#  68  queue_time_ms_ibeta2_crops_far_img           9794 non-null   float32
#  69  time_ms_ibeta2_full_near_img                 10586 non-null  float32
#  70  time_ms_ibeta2_full_far_img                  9794 non-null   float32
#  71  queue_time_ms_ibeta2_full_near_img           10586 non-null  float32
#  72  queue_time_ms_ibeta2_full_far_img            9794 non-null   float32
#  73  time_ms_ibeta2_clip_near_img                 10586 non-null  float32
#  74  time_ms_ibeta2_clip_far_img                  9794 non-null   float32
#  75  queue_time_ms_ibeta2_clip_near_img           10586 non-null  float32
#  76  queue_time_ms_ibeta2_clip_far_img            9794 non-null   float32
#  77  time_ms_geometry_check                       11128 non-null  float32
#  78  queue_time_ms_geometry_check                 11128 non-null  float32
# dtypes: category(4), float32(62), int64(4), object(6), uint16(3)
# memory usage: 4.7+ MB
# None
#   api_hash    user_name  file_token service  summary_code summary_status  \
# 0  02bc5e7  user_name_1  HLqbPi2Mbg    main          1400             ok
# 1  02bc5e7  user_name_1  DQktwYCPMA    main          1400             ok
# 2  02bc5e7  user_name_1  5RIpjp7e4Q    main          1400             ok
# 3  02bc5e7  user_name_1  Csl5ZGg2Jg    main          1400             ok
# 4  02bc5e7  user_name_1  7RUtj4FLag    main           302          error
#
#       summary_desc  http_code  total_time_ms  \
# 0  antispoofing OK        200           2204
# 1  antispoofing OK        200           1837
# 2  antispoofing OK        200           1936
# 3  antispoofing OK        200           1640
# 4        blur/haze        200            919
#
#                                date  ... time_ms_ibeta2_full_near_img  \
# 0  2025-01-08T22:10:36.542487-05:00  ...                         83.0
# 1  2025-01-08T22:14:12.653531-05:00  ...                         40.0
# 2  2025-01-08T22:16:10.768124-05:00  ...                         31.0
# 3  2025-01-08T22:16:14.887930-05:00  ...                         36.0
# 4  2025-01-08T22:28:01.054463-05:00  ...                          NaN
#
#   time_ms_ibeta2_full_far_img queue_time_ms_ibeta2_full_near_img  \
# 0                        83.0                                6.0
# 1                        28.0                                3.0
# 2                        58.0                                3.0
# 3                        60.0                                2.0
# 4                         NaN                                NaN
#
#    queue_time_ms_ibeta2_full_far_img  time_ms_ibeta2_clip_near_img  \
# 0                                2.0                           9.0
# 1                                1.0                           7.0
# 2                                3.0                           9.0
# 3                                2.0                          11.0
# 4                                NaN                           NaN
#
#    time_ms_ibeta2_clip_far_img  queue_time_ms_ibeta2_clip_near_img  \
# 0                          9.0                                 3.0
# 1                         16.0                                 2.0
# 2                         14.0                                 3.0
# 3                         10.0                                 2.0
# 4                          NaN                                 NaN
#
#    queue_time_ms_ibeta2_clip_far_img  time_ms_geometry_check  \
# 0                                2.0                    17.0
# 1                                2.0                     8.0
# 2                                2.0                     5.0
# 3                                1.0                    23.0
# 4                                NaN                     NaN
#
#    queue_time_ms_geometry_check
# 0                           2.0
# 1                           1.0
# 2                           1.0
# 3                           2.0
# 4                           NaN
#
# [5 rows x 79 columns]

# %% [markdown]
# Create SQLAlqchemy Engine

# %%
# Crear el motor de SQLAlchemy
engine = create_engine(f"postgresql://{db_user}:{db_password}@{db_host}:{db_port}/{db_name}")

# %% [markdown]
# Drop Table if Neccesary

# %%
# Borrar la tabla 'etl_staging_table_final_workshop' #Staging table
# Borrar la tabla 'etl_transformed_table_final_workshop' #Transformed table
# with engine.connect() as conn:
#     conn.execute(text("DROP TABLE IF EXISTS etl_staging_table_final_workshop"))
#     print("Tabla 'tabla_etl' borrada exitosamente en PostgreSQL.")

# %% [markdown]
# Staging Raw Data

# %%
db_table_name = "etl_staging_table_final_workshop"
df.to_sql(db_table_name, engine, if_exists='append', index=False)

print(f"DataFrame guardado exitosamente en la tabla {db_table_name} en PostgreSQL.")
# Out:
# DataFrame guardado exitosamente en la tabla etl_staging_table_final_workshop en PostgreSQL.

# %% [markdown]
# Loading / Reading Staging Table

# %%
db_table_name = "etl_staging_table_final_workshop"
with engine.connect() as conn:
    df_staging = pd.read_sql(f"SELECT * FROM {db_table_name}", conn)

print(df_staging.info())
print(df_staging.describe())
df_staging.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14654 entries, 0 to 14653
# Data columns (total 79 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   api_hash                                     14654 non-null  object
#  1   user_name                                    14654 non-null  object
#  2   file_token                                   14654 non-null  object
#  3   service                                      14654 non-null  object
#  4   summary_code                                 14654 non-null  int64
#  5   summary_status                               14654 non-null  object
#  6   summary_desc                                 14654 non-null  object
#  7   http_code                                    14654 non-null  int64
#  8   total_time_ms                                14654 non-null  int64
#  9   date                                         14654 non-null  object
#  10  procesoConvenioGuid                          14654 non-null  object
#  11  convenio                                     14654 non-null  object
#  12  documento                                    14654 non-null  object
#  13  img_size_near_img_width                      14654 non-null  int64
#  14  img_size_near_img_height                     14654 non-null  int64
#  15  img_size_far_img_width                       14654 non-null  int64
#  16  img_size_far_img_height                      14654 non-null  int64
#  17  score_liqe_near_img                          13593 non-null  float64
#  18  score_liqe_far_img                           11915 non-null  float64
#  19  score_topiq_near_img                         13593 non-null  float64
#  20  score_topiq_far_img                          11915 non-null  float64
#  21  score_sharpness_classic_metrics_near_img     13593 non-null  float64
#  22  score_sharpness_classic_metrics_far_img      11915 non-null  float64
#  23  score_colorfulness_classic_metrics_near_img  13593 non-null  float64
#  24  score_colorfulness_classic_metrics_far_img   11915 non-null  float64
#  25  score_contrast_classic_metrics_near_img      13593 non-null  float64
#  26  score_contrast_classic_metrics_far_img       11915 non-null  float64
#  27  score_brightness_classic_metrics_near_img    13593 non-null  float64
#  28  score_brightness_classic_metrics_far_img     11915 non-null  float64
#  29  score_blur_score_classic_metrics_near_img    13593 non-null  float64
#  30  score_blur_score_classic_metrics_far_img     11915 non-null  float64
#  31  score_svd_score_classic_metrics_near_img     13593 non-null  float64
#  32  score_svd_score_classic_metrics_far_img      11915 non-null  float64
#  33  prob_as_35_selfies_near_img                  10586 non-null  float64
#  34  prob_as_35_selfies_far_img                   9794 non-null   float64
#  35  prob_ibeta2_crops_near_img                   10586 non-null  float64
#  36  prob_ibeta2_crops_far_img                    9794 non-null   float64
#  37  prob_ibeta2_full_near_img                    10586 non-null  float64
#  38  prob_ibeta2_full_far_img                     9794 non-null   float64
#  39  prob_ibeta2_clip_near_img                    10586 non-null  float64
#  40  prob_ibeta2_clip_far_img                     9794 non-null   float64
#  41  prob_as_heuristics_near_img                  10586 non-null  float64
#  42  prob_as_heuristics_far_img                   9794 non-null   float64
#  43  time_ms_accessory_detector_near_img          14654 non-null  float64
#  44  time_ms_accessory_detector_far_img           14513 non-null  float64
#  45  queue_time_ms_accessory_detector_near_img    14654 non-null  float64
#  46  queue_time_ms_accessory_detector_far_img     14513 non-null  float64
#  47  time_ms_face_detector_near_img               14457 non-null  float64
#  48  time_ms_face_detector_far_img                14075 non-null  float64
#  49  queue_time_ms_face_detector_near_img         14457 non-null  float64
#  50  queue_time_ms_face_detector_far_img          14075 non-null  float64
#  51  time_ms_liqe_near_img                        13593 non-null  float64
#  52  time_ms_liqe_far_img                         11915 non-null  float64
#  53  queue_time_ms_liqe_near_img                  13593 non-null  float64
#  54  queue_time_ms_liqe_far_img                   11915 non-null  float64
#  55  time_ms_topiq_near_img                       13593 non-null  float64
#  56  time_ms_topiq_far_img                        11915 non-null  float64
#  57  queue_time_ms_topiq_near_img                 13593 non-null  float64
#  58  queue_time_ms_topiq_far_img                  11915 non-null  float64
#  59  time_ms_classic_metrics_near_img             13593 non-null  float64
#  60  time_ms_classic_metrics_far_img              11915 non-null  float64
#  61  time_ms_as_35_selfies_near_img               10586 non-null  float64
#  62  time_ms_as_35_selfies_far_img                9794 non-null   float64
#  63  queue_time_ms_as_35_selfies_near_img         10586 non-null  float64
#  64  queue_time_ms_as_35_selfies_far_img          9794 non-null   float64
#  65  time_ms_ibeta2_crops_near_img                10586 non-null  float64
#  66  time_ms_ibeta2_crops_far_img                 9794 non-null   float64
#  67  queue_time_ms_ibeta2_crops_near_img          10586 non-null  float64
#  68  queue_time_ms_ibeta2_crops_far_img           9794 non-null   float64
#  69  time_ms_ibeta2_full_near_img                 10586 non-null  float64
#  70  time_ms_ibeta2_full_far_img                  9794 non-null   float64
#  71  queue_time_ms_ibeta2_full_near_img           10586 non-null  float64
#  72  queue_time_ms_ibeta2_full_far_img            9794 non-null   float64
#  73  time_ms_ibeta2_clip_near_img                 10586 non-null  float64
#  74  time_ms_ibeta2_clip_far_img                  9794 non-null   float64
#  75  queue_time_ms_ibeta2_clip_near_img           10586 non-null  float64
#  76  queue_time_ms_ibeta2_clip_far_img            9794 non-null   float64
#  77  time_ms_geometry_check                       11128 non-null  float64
#  78  queue_time_ms_geometry_check                 11128 non-null  float64
# dtypes: float64(62), int64(7), object(10)
# memory usage: 8.8+ MB
# None
#        summary_code  http_code  total_time_ms  img_size_near_img_width  \
# count  14654.000000    14654.0   14654.000000             14654.000000
# mean    1197.237341      200.0    1994.429507               740.515013
# std      583.275790        0.0    1361.465970               280.978414
# min      102.000000      200.0       0.000000               414.000000
# 25%     1400.000000      200.0    1207.750000               590.000000
# 50%     1400.000000      200.0    1749.000000               590.000000
# 75%     1400.000000      200.0    1954.750000               736.000000
# max     3002.000000      200.0    9114.000000              1440.000000
#
#        img_size_near_img_height  img_size_far_img_width  \
# count              14654.000000            14654.000000
# mean                1076.862495              740.624198
# std                  409.914160              281.032593
# min                  480.000000              414.000000
# 25%                  896.000000              590.000000
# 50%                  896.000000              590.000000
# 75%                 1280.000000              736.000000
# max                 1920.000000             1440.000000
#
#        img_size_far_img_height  score_liqe_near_img  score_liqe_far_img  \
# count             14654.000000         13593.000000        11915.000000
# mean               1076.753310             2.942604            3.000815
# std                 409.966582             1.383330            1.313958
# min                 480.000000             1.000000            1.000100
# 25%                 896.000000             1.607400            1.919600
# 50%                 896.000000             2.835900            2.852700
# 75%                1280.000000             4.188000            4.196000
# max                1920.000000             5.000000            5.000000
#
#        score_topiq_near_img  ...  time_ms_ibeta2_full_near_img  \
# count          13593.000000  ...                  10586.000000
# mean               0.565350  ...                     68.776781
# std                0.171892  ...                     27.455818
# min               -1.000000  ...                     28.000000
# 25%                0.482500  ...                     45.000000
# 50%                0.573700  ...                     66.000000
# 75%                0.677800  ...                     87.000000
# max                0.925100  ...                    256.000000
#
#        time_ms_ibeta2_full_far_img  queue_time_ms_ibeta2_full_near_img  \
# count                  9794.000000                        10586.000000
# mean                     63.263324                           12.068865
# std                      25.070606                           28.162630
# min                      28.000000                            1.000000
# 25%                      43.000000                            3.000000
# 50%                      60.000000                            4.000000
# 75%                      79.000000                            7.000000
# max                     217.000000                          600.000000
#
#        queue_time_ms_ibeta2_full_far_img  time_ms_ibeta2_clip_near_img  \
# count                        9794.000000                  10586.000000
# mean                            8.964162                     16.890799
# std                            20.449479                     10.545265
# min                             1.000000                      6.000000
# 25%                             2.000000                      8.000000
# 50%                             3.000000                     15.000000
# 75%                             5.000000                     22.000000
# max                           543.000000                    106.000000
#
#        time_ms_ibeta2_clip_far_img  queue_time_ms_ibeta2_clip_near_img  \
# count                  9794.000000                        10586.000000
# mean                     16.678477                            9.733705
# std                      10.745016                           19.328931
# min                       6.000000                            1.000000
# 25%                       8.000000                            3.000000
# 50%                      14.000000                            3.000000
# 75%                      22.000000                            6.000000
# max                     111.000000                          561.000000
#
#        queue_time_ms_ibeta2_clip_far_img  time_ms_geometry_check  \
# count                        9794.000000            11128.000000
# mean                            7.028793               12.515636
# std                            14.610872               15.040454
# min                             1.000000                5.000000
# 25%                             2.000000                6.000000
# 50%                             2.000000                6.000000
# 75%                             3.000000                9.000000
# max                           418.000000              162.000000
#
#        queue_time_ms_geometry_check
# count                  11128.000000
# mean                       0.878235
# std                        1.397658
# min                        0.000000
# 25%                        1.000000
# 50%                        1.000000
# 75%                        1.000000
# max                      101.000000
#
# [8 rows x 69 columns]
#   api_hash    user_name  file_token service  summary_code summary_status  \
# 0  02bc5e7  user_name_1  HLqbPi2Mbg    main          1400             ok
# 1  02bc5e7  user_name_1  DQktwYCPMA    main          1400             ok
# 2  02bc5e7  user_name_1  5RIpjp7e4Q    main          1400             ok
# 3  02bc5e7  user_name_1  Csl5ZGg2Jg    main          1400             ok
# 4  02bc5e7  user_name_1  7RUtj4FLag    main           302          error
#
#       summary_desc  http_code  total_time_ms  \
# 0  antispoofing OK        200           2204
# 1  antispoofing OK        200           1837
# 2  antispoofing OK        200           1936
# 3  antispoofing OK        200           1640
# 4        blur/haze        200            919
#
#                                date  ... time_ms_ibeta2_full_near_img  \
# 0  2025-01-08T22:10:36.542487-05:00  ...                         83.0
# 1  2025-01-08T22:14:12.653531-05:00  ...                         40.0
# 2  2025-01-08T22:16:10.768124-05:00  ...                         31.0
# 3  2025-01-08T22:16:14.887930-05:00  ...                         36.0
# 4  2025-01-08T22:28:01.054463-05:00  ...                          NaN
#
#   time_ms_ibeta2_full_far_img queue_time_ms_ibeta2_full_near_img  \
# 0                        83.0                                6.0
# 1                        28.0                                3.0
# 2                        58.0                                3.0
# 3                        60.0                                2.0
# 4                         NaN                                NaN
#
#    queue_time_ms_ibeta2_full_far_img  time_ms_ibeta2_clip_near_img  \
# 0                                2.0                           9.0
# 1                                1.0                           7.0
# 2                                3.0                           9.0
# 3                                2.0                          11.0
# 4                                NaN                           NaN
#
#    time_ms_ibeta2_clip_far_img  queue_time_ms_ibeta2_clip_near_img  \
# 0                          9.0                                 3.0
# 1                         16.0                                 2.0
# 2                         14.0                                 3.0
# 3                         10.0                                 2.0
# 4                          NaN                                 NaN
#
#    queue_time_ms_ibeta2_clip_far_img  time_ms_geometry_check  \
# 0                                2.0                    17.0
# 1                                2.0                     8.0
# 2                                2.0                     5.0
# 3                                1.0                    23.0
# 4                                NaN                     NaN
#
#    queue_time_ms_geometry_check
# 0                           2.0
# 1                           1.0
# 2                           1.0
# 3                           2.0
# 4                           NaN
#
# [5 rows x 79 columns]
